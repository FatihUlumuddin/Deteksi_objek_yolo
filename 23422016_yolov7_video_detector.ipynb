# %% [markdown]
# <a href="https://colab.research.google.com/github/FatihUlumuddin/Deteksi_objek_yolo/blob/main/23422016_yolov7_video_detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 33.69 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %%
# %cd yolov7
# Out:
# [Errno 2] No such file or directory: 'yolov7'
# /content/yolov7

# %%
# !pip install -r requirements.txt

# %%
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Out:
# --2025-06-16 02:07:53--  https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from google.colab import files

# Upload video
uploaded = files.upload()  # pilih file video (misalnya mp4)

# Jalankan deteksi objek
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source <nama_file_video.mp4>
# Out:
#      <input type="file" id="files-80c55c1a-ad6e-437f-944c-e5762e245219" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-80c55c1a-ad6e-437f-944c-e5762e245219">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source cctv_malang_kedung_kandang.mp4
# Out:
# Namespace(weights=['yolov7.pt'], source='cctv_malang_kedung_kandang.mp4', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 v0.1-128-ga207844 torch 2.0.1+cu118 CUDA:0 (Tesla T4, 15095.0625MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# Model Summary: 306 layers, 36905341 parameters, 6652669 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
import os
print(os.listdir('runs/detect'))
# Out:
# ['exp', 'exp3', 'exp4', 'exp2']

# %%
print(os.listdir('runs/detect/exp4'))
# Out:
# ['cctv_malang_kedung_kandang.mp4']

# %%
from google.colab import files
files.download('runs/detect/exp4/cctv_malang_kedung_kandang.mp4')
